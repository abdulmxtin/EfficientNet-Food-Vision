# %% [markdown]
# # MileStone Project 1: Food Vision 101

# %%
import tensorflow as tf

# %% [markdown]
# ## Check GPU
#
# We are going to use mixed-precision training which requires the GPU to have a compute capability > 7. Due to which we are going to use Tesla T4 (only mixed precision compatibility offered by google collab).

# %%
# !nvidia-smi -L
# Out:
# GPU 0: Tesla T4 (UUID: GPU-51c465c0-2955-0cd1-483d-f1921501f009)

# %% [markdown]
# ## Get Helper Functions

# %%
# !wget https://raw.githubusercontent.com/ShataayuM/AIML/refs/heads/main/helper_functions.py
# Out:
# --2025-09-13 14:26:58--  https://raw.githubusercontent.com/ShataayuM/AIML/refs/heads/main/helper_functions.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10246 (10K) [text/plain]
# Saving to: ‘helper_functions.py’
#
# helper_functions.py 100%[===================>]  10.01K  --.-KB/s    in 0s
#
# 2025-09-13 14:26:59 (99.4 MB/s) - ‘helper_functions.py’ saved [10246/10246]

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.74.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.8.3)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.9)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)

# %%
# Import series of helper functions:
from helper_functions import create_tensorboard_callback, plot_loss_curves, compare_historys

# %% [markdown]
# ## Downloading the Data and Prepareing it

# %% [markdown]
# Step 1: Download & extract manually

# %%
# !wget http://data.vision.ee.ethz.ch/cvl/food-101.tar.gz
# !tar -xvzf food-101.tar.gz
# Out:
# Streaming output truncated to the last 5000 lines.
# food-101/images/fish_and_chips/1495386.jpg
# food-101/images/fish_and_chips/2286768.jpg
# food-101/images/fish_and_chips/1614554.jpg
# food-101/images/fish_and_chips/2255974.jpg
# food-101/images/fish_and_chips/184654.jpg
# food-101/images/fish_and_chips/1547043.jpg
# food-101/images/fish_and_chips/1286350.jpg
# food-101/images/fish_and_chips/1506981.jpg
# food-101/images/fish_and_chips/1668039.jpg
# food-101/images/fish_and_chips/3783246.jpg
# food-101/images/fish_and_chips/2737696.jpg
# food-101/images/fish_and_chips/2415083.jpg
# food-101/images/fish_and_chips/3258877.jpg
# food-101/images/fish_and_chips/1128671.jpg
# food-101/images/fish_and_chips/3584880.jpg
# food-101/images/fish_and_chips/1118825.jpg
# food-101/images/fish_and_chips/1225146.jpg
# food-101/images/fish_and_chips/3196765.jpg
# food-101/images/fish_and_chips/2497717.jpg
# food-101/images/fish_and_chips/3226554.jpg
# food-101/images/fish_and_chips/3655543.jpg
# food-101/images/fish_and_chips/403380.jpg
# food-101/images/fish_and_chips/1464068.jpg
# food-101/images/fish_and_chips/3710354.jpg
# food-101/images/fish_and_chips/3310198.jpg
# food-101/images/fish_and_chips/2716580.jpg
# food-101/images/fish_and_chips/1885933.jpg
# food-101/images/fish_and_chips/1351973.jpg
# food-101/images/fish_and_chips/3426793.jpg
# food-101/images/fish_and_chips/2771852.jpg
# food-101/images/fish_and_chips/3332139.jpg
# food-101/images/fish_and_chips/463619.jpg
# food-101/images/fish_and_chips/3172727.jpg
# food-101/images/fish_and_chips/113713.jpg
# food-101/images/fish_and_chips/1449739.jpg
# food-101/images/fish_and_chips/1035379.jpg
# food-101/images/fish_and_chips/3647175.jpg
# food-101/images/fish_and_chips/3128454.jpg
# food-101/images/fish_and_chips/1857456.jpg
# food-101/images/fish_and_chips/1916894.jpg
# food-101/images/fish_and_chips/2849652.jpg
# food-101/images/fish_and_chips/557498.jpg
# food-101/images/fish_and_chips/3212580.jpg
# food-101/images/fish_and_chips/1979715.jpg
# food-101/images/fish_and_chips/2040566.jpg
# food-101/images/fish_and_chips/2689020.jpg
# food-101/images/fish_and_chips/3149155.jpg
# food-101/images/fish_and_chips/3087259.jpg
# food-101/images/fish_and_chips/1243003.jpg
# food-101/images/fish_and_chips/2515480.jpg
# food-101/images/fish_and_chips/3718806.jpg
# food-101/images/fish_and_chips/3606215.jpg
# food-101/images/fish_and_chips/599483.jpg
# food-101/images/fish_and_chips/502324.jpg
# food-101/images/fish_and_chips/2694694.jpg
# food-101/images/fish_and_chips/3912593.jpg
# food-101/images/fish_and_chips/3887975.jpg
# food-101/images/fish_and_chips/2287453.jpg
# food-101/images/fish_and_chips/724722.jpg
# food-101/images/fish_and_chips/1865683.jpg
# food-101/images/fish_and_chips/3291877.jpg
# food-101/images/fish_and_chips/2195578.jpg
# food-101/images/fish_and_chips/940509.jpg
# food-101/images/fish_and_chips/1347751.jpg
# food-101/images/fish_and_chips/2799763.jpg
# food-101/images/fish_and_chips/459683.jpg
# food-101/images/fish_and_chips/1830225.jpg
# food-101/images/fish_and_chips/3196074.jpg
# food-101/images/fish_and_chips/2249482.jpg
# food-101/images/fish_and_chips/1313090.jpg
# food-101/images/fish_and_chips/2261540.jpg
# food-101/images/fish_and_chips/2967524.jpg
# food-101/images/fish_and_chips/3616236.jpg
# food-101/images/fish_and_chips/939741.jpg
# food-101/images/fish_and_chips/2865060.jpg
# food-101/images/fish_and_chips/1421894.jpg
# food-101/images/fish_and_chips/549848.jpg
# food-101/images/fish_and_chips/2009997.jpg
# food-101/images/fish_and_chips/3092024.jpg
# food-101/images/fish_and_chips/3158098.jpg
# food-101/images/fish_and_chips/3206734.jpg
# food-101/images/fish_and_chips/3241574.jpg
# food-101/images/fish_and_chips/2501991.jpg
# food-101/images/fish_and_chips/2500832.jpg
# food-101/images/fish_and_chips/3126572.jpg
# food-101/images/fish_and_chips/3079363.jpg
# food-101/images/fish_and_chips/3700549.jpg
# food-101/images/fish_and_chips/2879070.jpg
# food-101/images/fish_and_chips/1160615.jpg
# food-101/images/fish_and_chips/2562886.jpg
# food-101/images/fish_and_chips/3301358.jpg
# food-101/images/fish_and_chips/1609984.jpg
# food-101/images/fish_and_chips/2542059.jpg
# food-101/images/fish_and_chips/2338388.jpg
# food-101/images/fish_and_chips/2480161.jpg
# food-101/images/fish_and_chips/970134.jpg
# food-101/images/fish_and_chips/1424554.jpg
# food-101/images/fish_and_chips/2179558.jpg
# food-101/images/fish_and_chips/3370146.jpg
# food-101/images/fish_and_chips/2440249.jpg
# food-101/images/fish_and_chips/742698.jpg
# food-101/images/fish_and_chips/3728426.jpg
# food-101/images/fish_and_chips/3394055.jpg
# food-101/images/fish_and_chips/1976788.jpg
# food-101/images/fish_and_chips/1435827.jpg
# food-101/images/fish_and_chips/689347.jpg
# food-101/images/fish_and_chips/2571982.jpg
# food-101/images/fish_and_chips/996228.jpg
# food-101/images/fish_and_chips/26018.jpg
# food-101/images/fish_and_chips/534192.jpg
# food-101/images/fish_and_chips/2679502.jpg
# food-101/images/fish_and_chips/2331021.jpg
# food-101/images/fish_and_chips/948355.jpg
# food-101/images/fish_and_chips/1003726.jpg
# food-101/images/fish_and_chips/497629.jpg
# food-101/images/fish_and_chips/3673477.jpg
# food-101/images/fish_and_chips/1768927.jpg
# food-101/images/fish_and_chips/2486391.jpg
# food-101/images/fish_and_chips/2734225.jpg
# food-101/images/fish_and_chips/141802.jpg
# food-101/images/fish_and_chips/2484873.jpg
# food-101/images/fish_and_chips/3262032.jpg
# food-101/images/fish_and_chips/1372915.jpg
# food-101/images/fish_and_chips/2463894.jpg
# food-101/images/fish_and_chips/261170.jpg
# food-101/images/fish_and_chips/3729426.jpg
# food-101/images/fish_and_chips/3715232.jpg
# food-101/images/fish_and_chips/1853290.jpg
# food-101/images/fish_and_chips/162295.jpg
# food-101/images/fish_and_chips/191445.jpg
# food-101/images/fish_and_chips/2122729.jpg
# food-101/images/fish_and_chips/773476.jpg
# food-101/images/fish_and_chips/2988646.jpg
# food-101/images/fish_and_chips/1915822.jpg
# food-101/images/fish_and_chips/2269736.jpg
# food-101/images/fish_and_chips/1086970.jpg
# food-101/images/fish_and_chips/2343592.jpg
# food-101/images/fish_and_chips/633730.jpg
# food-101/images/fish_and_chips/3750241.jpg
# food-101/images/fish_and_chips/1490827.jpg
# food-101/images/fish_and_chips/3852307.jpg
# food-101/images/fish_and_chips/3792391.jpg
# food-101/images/fish_and_chips/2593057.jpg
# food-101/images/fish_and_chips/1709357.jpg
# food-101/images/fish_and_chips/885620.jpg
# food-101/images/fish_and_chips/517956.jpg
# food-101/images/fish_and_chips/3502049.jpg
# food-101/images/fish_and_chips/2372879.jpg
# food-101/images/fish_and_chips/876010.jpg
# food-101/images/fish_and_chips/3730997.jpg
# food-101/images/fish_and_chips/3852711.jpg
# food-101/images/fish_and_chips/2619595.jpg
# food-101/images/fish_and_chips/5705.jpg
# food-101/images/fish_and_chips/3475039.jpg
# food-101/images/fish_and_chips/3797876.jpg
# food-101/images/fish_and_chips/705488.jpg
# food-101/images/fish_and_chips/2116208.jpg
# food-101/images/fish_and_chips/609576.jpg
# food-101/images/fish_and_chips/2098568.jpg
# food-101/images/fish_and_chips/2065591.jpg
# food-101/images/fish_and_chips/750574.jpg
# food-101/images/fish_and_chips/1454022.jpg
# food-101/images/fish_and_chips/267279.jpg
# food-101/images/fish_and_chips/2919201.jpg
# food-101/images/fish_and_chips/887703.jpg
# food-101/images/fish_and_chips/3783383.jpg
# food-101/images/fish_and_chips/975592.jpg
# food-101/images/fish_and_chips/794255.jpg
# food-101/images/fish_and_chips/533951.jpg
# food-101/images/fish_and_chips/3119479.jpg
# food-101/images/fish_and_chips/825429.jpg
# food-101/images/fish_and_chips/3014220.jpg
# food-101/images/fish_and_chips/1995729.jpg
# food-101/images/fish_and_chips/1230813.jpg
# food-101/images/fish_and_chips/3799762.jpg
# food-101/images/fish_and_chips/961018.jpg
# food-101/images/fish_and_chips/1770652.jpg
# food-101/images/fish_and_chips/3211680.jpg
# food-101/images/fish_and_chips/1662738.jpg
# food-101/images/fish_and_chips/43435.jpg
# food-101/images/fish_and_chips/2453607.jpg
# food-101/images/fish_and_chips/2299054.jpg
# food-101/images/fish_and_chips/2188688.jpg
# food-101/images/fish_and_chips/3582300.jpg
# food-101/images/fish_and_chips/2072610.jpg
# food-101/images/fish_and_chips/3219720.jpg
# food-101/images/fish_and_chips/626758.jpg
# food-101/images/fish_and_chips/2816095.jpg
# food-101/images/fish_and_chips/2598407.jpg
# food-101/images/fish_and_chips/1831857.jpg
# food-101/images/fish_and_chips/2207374.jpg
# food-101/images/fish_and_chips/335272.jpg
# food-101/images/fish_and_chips/312158.jpg
# food-101/images/fish_and_chips/2713291.jpg
# food-101/images/fish_and_chips/3632964.jpg
# food-101/images/fish_and_chips/2616536.jpg
# food-101/images/fish_and_chips/2232596.jpg
# food-101/images/fish_and_chips/2531288.jpg
# food-101/images/fish_and_chips/822973.jpg
# food-101/images/fish_and_chips/1291168.jpg
# food-101/images/fish_and_chips/1489485.jpg
# food-101/images/fish_and_chips/2864614.jpg
# food-101/images/fish_and_chips/3721416.jpg
# food-101/images/fish_and_chips/674163.jpg
# food-101/images/fish_and_chips/762973.jpg
# food-101/images/fish_and_chips/2673675.jpg
# food-101/images/fish_and_chips/524965.jpg
# food-101/images/fish_and_chips/534824.jpg
# food-101/images/fish_and_chips/1249038.jpg
# food-101/images/fish_and_chips/2063782.jpg
# food-101/images/fish_and_chips/123353.jpg
# food-101/images/fish_and_chips/1217131.jpg
# food-101/images/fish_and_chips/3363705.jpg
# food-101/images/fish_and_chips/1782710.jpg
# food-101/images/fish_and_chips/3259415.jpg
# food-101/images/fish_and_chips/918183.jpg
# food-101/images/fish_and_chips/3089975.jpg
# food-101/images/fish_and_chips/1257070.jpg
# food-101/images/fish_and_chips/2483512.jpg
# food-101/images/fish_and_chips/1705939.jpg
# food-101/images/fish_and_chips/3595951.jpg
# food-101/images/fish_and_chips/647277.jpg
# food-101/images/fish_and_chips/164903.jpg
# food-101/images/fish_and_chips/926754.jpg
# food-101/images/fish_and_chips/55493.jpg
# food-101/images/fish_and_chips/1620759.jpg
# food-101/images/fish_and_chips/3334165.jpg
# food-101/images/fish_and_chips/3243309.jpg
# food-101/images/fish_and_chips/2530704.jpg
# food-101/images/fish_and_chips/1720941.jpg
# food-101/images/fish_and_chips/1953827.jpg
# food-101/images/fish_and_chips/895795.jpg
# food-101/images/fish_and_chips/3756148.jpg
# food-101/images/fish_and_chips/806759.jpg
# food-101/images/fish_and_chips/2009939.jpg
# food-101/images/fish_and_chips/1445435.jpg
# food-101/images/fish_and_chips/796657.jpg
# food-101/images/fish_and_chips/2204214.jpg
# food-101/images/fish_and_chips/2348219.jpg
# food-101/images/fish_and_chips/727087.jpg
# food-101/images/fish_and_chips/2347295.jpg
# food-101/images/fish_and_chips/896001.jpg
# food-101/images/fish_and_chips/3737541.jpg
# food-101/images/fish_and_chips/1889217.jpg
# food-101/images/fish_and_chips/186030.jpg
# food-101/images/fish_and_chips/1063281.jpg
# food-101/images/fish_and_chips/3471132.jpg
# food-101/images/fish_and_chips/1333853.jpg
# food-101/images/fish_and_chips/1684392.jpg
# food-101/images/fish_and_chips/642672.jpg
# food-101/images/fish_and_chips/818406.jpg
# food-101/images/fish_and_chips/1525416.jpg
# food-101/images/fish_and_chips/3007446.jpg
# food-101/images/fish_and_chips/847753.jpg
# food-101/images/fish_and_chips/164390.jpg
# food-101/images/fish_and_chips/2533644.jpg
# food-101/images/fish_and_chips/1168170.jpg
# food-101/images/fish_and_chips/2562921.jpg
# food-101/images/fish_and_chips/1054214.jpg
# food-101/images/fish_and_chips/3867533.jpg
# food-101/images/fish_and_chips/3282640.jpg
# food-101/images/fish_and_chips/2813636.jpg
# food-101/images/fish_and_chips/770751.jpg
# food-101/images/fish_and_chips/2802331.jpg
# food-101/images/fish_and_chips/2969663.jpg
# food-101/images/fish_and_chips/554726.jpg
# food-101/images/fish_and_chips/19498.jpg
# food-101/images/fish_and_chips/996512.jpg
# food-101/images/fish_and_chips/47643.jpg
# food-101/images/fish_and_chips/2750074.jpg
# food-101/images/fish_and_chips/723927.jpg
# food-101/images/fish_and_chips/2353008.jpg
# food-101/images/fish_and_chips/2710198.jpg
# food-101/images/fish_and_chips/2434306.jpg
# food-101/images/fish_and_chips/2656495.jpg
# food-101/images/fish_and_chips/588986.jpg
# food-101/images/fish_and_chips/1923647.jpg
# food-101/images/fish_and_chips/2225942.jpg
# food-101/images/fish_and_chips/857919.jpg
# food-101/images/fish_and_chips/3411914.jpg
# food-101/images/fish_and_chips/1477023.jpg
# food-101/images/fish_and_chips/1278726.jpg
# food-101/images/fish_and_chips/1900727.jpg
# food-101/images/fish_and_chips/2843310.jpg
# food-101/images/fish_and_chips/3746418.jpg
# food-101/images/fish_and_chips/637644.jpg
# food-101/images/fish_and_chips/1519427.jpg
# food-101/images/fish_and_chips/1179224.jpg
# food-101/images/fish_and_chips/778525.jpg
# food-101/images/fish_and_chips/2595440.jpg
# food-101/images/fish_and_chips/2939722.jpg
# food-101/images/fish_and_chips/2519024.jpg
# food-101/images/fish_and_chips/1811502.jpg
# food-101/images/fish_and_chips/982706.jpg
# food-101/images/fish_and_chips/3087407.jpg
# food-101/images/fish_and_chips/251026.jpg
# food-101/images/fish_and_chips/888785.jpg
# food-101/images/fish_and_chips/2154983.jpg
# food-101/images/fish_and_chips/2694224.jpg
# food-101/images/fish_and_chips/3093627.jpg
# food-101/images/fish_and_chips/1820501.jpg
# food-101/images/fish_and_chips/1828092.jpg
# food-101/images/fish_and_chips/2954945.jpg
# food-101/images/fish_and_chips/568927.jpg
# food-101/images/fish_and_chips/463198.jpg
# food-101/images/fish_and_chips/3912077.jpg
# food-101/images/fish_and_chips/1727465.jpg
# food-101/images/fish_and_chips/3796303.jpg
# food-101/images/fish_and_chips/372667.jpg
# food-101/images/fish_and_chips/2572330.jpg
# food-101/images/fish_and_chips/490014.jpg
# food-101/images/fish_and_chips/2885728.jpg
# food-101/images/fish_and_chips/1012859.jpg
# food-101/images/fish_and_chips/379055.jpg
# food-101/images/fish_and_chips/210499.jpg
# food-101/images/fish_and_chips/174111.jpg
# food-101/images/fish_and_chips/3686822.jpg
# food-101/images/fish_and_chips/529653.jpg
# food-101/images/fish_and_chips/3251156.jpg
# food-101/images/fish_and_chips/1222459.jpg
# food-101/images/fish_and_chips/1916348.jpg
# food-101/images/fish_and_chips/3748224.jpg
# food-101/images/fish_and_chips/292001.jpg
# food-101/images/fish_and_chips/3292110.jpg
# food-101/images/fish_and_chips/2128368.jpg
# food-101/images/fish_and_chips/2538669.jpg
# food-101/images/fish_and_chips/556207.jpg
# food-101/images/fish_and_chips/3834954.jpg
# food-101/images/fish_and_chips/385693.jpg
# food-101/images/fish_and_chips/1435401.jpg
# food-101/images/fish_and_chips/52739.jpg
# food-101/images/fish_and_chips/195363.jpg
# food-101/images/fish_and_chips/38171.jpg
# food-101/images/fish_and_chips/303466.jpg
# food-101/images/fish_and_chips/95332.jpg
# food-101/images/fish_and_chips/2463876.jpg
# food-101/images/fish_and_chips/802254.jpg
# food-101/images/fish_and_chips/119967.jpg
# food-101/images/fish_and_chips/1756465.jpg
# food-101/images/fish_and_chips/969594.jpg
# food-101/images/fish_and_chips/2177542.jpg
# food-101/images/fish_and_chips/551010.jpg
# food-101/images/fish_and_chips/1484952.jpg
# food-101/images/fish_and_chips/287722.jpg
# food-101/images/fish_and_chips/1590683.jpg
# food-101/images/fish_and_chips/1110475.jpg
# food-101/images/fish_and_chips/2288389.jpg
# food-101/images/fish_and_chips/3087936.jpg
# food-101/images/fish_and_chips/3729531.jpg
# food-101/images/fish_and_chips/3209704.jpg
# food-101/images/fish_and_chips/2525181.jpg
# food-101/images/fish_and_chips/893947.jpg
# food-101/images/fish_and_chips/584991.jpg
# food-101/images/fish_and_chips/359219.jpg
# food-101/images/fish_and_chips/995133.jpg
# food-101/images/fish_and_chips/3666139.jpg
# food-101/images/fish_and_chips/762453.jpg
# food-101/images/fish_and_chips/1396384.jpg
# food-101/images/fish_and_chips/2268904.jpg
# food-101/images/fish_and_chips/2263884.jpg
# food-101/images/fish_and_chips/2165672.jpg
# food-101/images/fish_and_chips/3550882.jpg
# food-101/images/fish_and_chips/3672318.jpg
# food-101/images/fish_and_chips/1607695.jpg
# food-101/images/fish_and_chips/691890.jpg
# food-101/images/fish_and_chips/1407271.jpg
# food-101/images/fish_and_chips/128397.jpg
# food-101/images/fish_and_chips/1639611.jpg
# food-101/images/fish_and_chips/377460.jpg
# food-101/images/fish_and_chips/311469.jpg
# food-101/images/fish_and_chips/3795446.jpg
# food-101/images/fish_and_chips/864911.jpg
# food-101/images/fish_and_chips/2583722.jpg
# food-101/images/fish_and_chips/1951420.jpg
# food-101/images/fish_and_chips/3525033.jpg
# food-101/images/fish_and_chips/2206056.jpg
# food-101/images/fish_and_chips/2621475.jpg
# food-101/images/fish_and_chips/2535159.jpg
# food-101/images/fish_and_chips/3330276.jpg
# food-101/images/fish_and_chips/2816197.jpg
# food-101/images/fish_and_chips/3758080.jpg
# food-101/images/fish_and_chips/1328579.jpg
# food-101/images/fish_and_chips/3504296.jpg
# food-101/images/fish_and_chips/1730402.jpg
# food-101/images/fish_and_chips/1890276.jpg
# food-101/images/fish_and_chips/3863090.jpg
# food-101/images/fish_and_chips/1746664.jpg
# food-101/images/fish_and_chips/2686378.jpg
# food-101/images/fish_and_chips/964750.jpg
# food-101/images/fish_and_chips/751024.jpg
# food-101/images/fish_and_chips/3669644.jpg
# food-101/images/fish_and_chips/2641783.jpg
# food-101/images/fish_and_chips/2364171.jpg
# food-101/images/fish_and_chips/1449699.jpg
# food-101/images/fish_and_chips/1159183.jpg
# food-101/images/fish_and_chips/2079080.jpg
# food-101/images/fish_and_chips/1505412.jpg
# food-101/images/fish_and_chips/3193654.jpg
# food-101/images/fish_and_chips/4128.jpg
# food-101/images/fish_and_chips/1386743.jpg
# food-101/images/fish_and_chips/3860849.jpg
# food-101/images/fish_and_chips/3837512.jpg
# food-101/images/fish_and_chips/1337673.jpg
# food-101/images/fish_and_chips/3469590.jpg
# food-101/images/fish_and_chips/3879054.jpg
# food-101/images/fish_and_chips/3857109.jpg
# food-101/images/fish_and_chips/655998.jpg
# food-101/images/fish_and_chips/1255503.jpg
# food-101/images/fish_and_chips/302932.jpg
# food-101/images/fish_and_chips/2318309.jpg
# food-101/images/fish_and_chips/889508.jpg
# food-101/images/fish_and_chips/3537615.jpg
# food-101/images/fish_and_chips/1680852.jpg
# food-101/images/fish_and_chips/3322515.jpg
# food-101/images/fish_and_chips/22716.jpg
# food-101/images/fish_and_chips/3340230.jpg
# food-101/images/fish_and_chips/1531249.jpg
# food-101/images/fish_and_chips/1085414.jpg
# food-101/images/fish_and_chips/3674016.jpg
# food-101/images/fish_and_chips/2060610.jpg
# food-101/images/fish_and_chips/2309890.jpg
# food-101/images/fish_and_chips/1971675.jpg
# food-101/images/fish_and_chips/3006202.jpg
# food-101/images/fish_and_chips/710495.jpg
# food-101/images/fish_and_chips/981299.jpg
# food-101/images/fish_and_chips/3756863.jpg
# food-101/images/fish_and_chips/673231.jpg
# food-101/images/fish_and_chips/3831484.jpg
# food-101/images/fish_and_chips/26665.jpg
# food-101/images/fish_and_chips/1868988.jpg
# food-101/images/fish_and_chips/3121471.jpg
# food-101/images/fish_and_chips/2750436.jpg
# food-101/images/fish_and_chips/2339438.jpg
# food-101/images/fish_and_chips/1585351.jpg
# food-101/images/fish_and_chips/764727.jpg
# food-101/images/fish_and_chips/3466493.jpg
# food-101/images/fish_and_chips/286820.jpg
# food-101/images/fish_and_chips/1775578.jpg
# food-101/images/fish_and_chips/3562485.jpg
# food-101/images/fish_and_chips/2294935.jpg
# food-101/images/fish_and_chips/1701079.jpg
# food-101/images/fish_and_chips/1426622.jpg
# food-101/images/fish_and_chips/1782768.jpg
# food-101/images/fish_and_chips/1799327.jpg
# food-101/images/fish_and_chips/1018454.jpg
# food-101/images/fish_and_chips/2838596.jpg
# food-101/images/fish_and_chips/2025645.jpg
# food-101/images/fish_and_chips/2716861.jpg
# food-101/images/fish_and_chips/3521924.jpg
# food-101/images/fish_and_chips/954741.jpg
# food-101/images/fish_and_chips/535233.jpg
# food-101/images/fish_and_chips/1164299.jpg
# food-101/images/fish_and_chips/2576819.jpg
# food-101/images/fish_and_chips/3904780.jpg
# food-101/images/fish_and_chips/2013768.jpg
# food-101/images/fish_and_chips/959768.jpg
# food-101/images/fish_and_chips/980125.jpg
# food-101/images/fish_and_chips/1808226.jpg
# food-101/images/fish_and_chips/2561516.jpg
# food-101/images/fish_and_chips/712528.jpg
# food-101/images/fish_and_chips/1374719.jpg
# food-101/images/fish_and_chips/1494905.jpg
# food-101/images/fish_and_chips/57512.jpg
# food-101/images/fish_and_chips/839870.jpg
# food-101/images/fish_and_chips/507353.jpg
# food-101/images/fish_and_chips/1126944.jpg
# food-101/images/fish_and_chips/3859059.jpg
# food-101/images/fish_and_chips/813266.jpg
# food-101/images/fish_and_chips/2242345.jpg
# food-101/images/fish_and_chips/2028565.jpg
# food-101/images/fish_and_chips/1393401.jpg
# food-101/images/fish_and_chips/1035054.jpg
# food-101/images/fish_and_chips/808936.jpg
# food-101/images/fish_and_chips/3444216.jpg
# food-101/images/fish_and_chips/2503977.jpg
# food-101/images/fish_and_chips/1814341.jpg
# food-101/images/fish_and_chips/3806847.jpg
# food-101/images/fish_and_chips/3399117.jpg
# food-101/images/fish_and_chips/3276750.jpg
# food-101/images/fish_and_chips/3222017.jpg
# food-101/images/fish_and_chips/3135126.jpg
# food-101/images/fish_and_chips/106755.jpg
# food-101/images/fish_and_chips/2228375.jpg
# food-101/images/fish_and_chips/1100043.jpg
# food-101/images/fish_and_chips/1360428.jpg
# food-101/images/fish_and_chips/2096389.jpg
# food-101/images/fish_and_chips/528885.jpg
# food-101/images/fish_and_chips/157122.jpg
# food-101/images/fish_and_chips/1897694.jpg
# food-101/images/fish_and_chips/2008704.jpg
# food-101/images/fish_and_chips/686802.jpg
# food-101/images/fish_and_chips/1106451.jpg
# food-101/images/fish_and_chips/3014070.jpg
# food-101/images/fish_and_chips/1090849.jpg
# food-101/images/fish_and_chips/3296215.jpg
# food-101/images/fish_and_chips/2007473.jpg
# food-101/images/fish_and_chips/352004.jpg
# food-101/images/fish_and_chips/590470.jpg
# food-101/images/fish_and_chips/250985.jpg
# food-101/images/fish_and_chips/852434.jpg
# food-101/images/fish_and_chips/916795.jpg
# food-101/images/fish_and_chips/1981389.jpg
# food-101/images/fish_and_chips/794402.jpg
# food-101/images/fish_and_chips/2107055.jpg
# food-101/images/fish_and_chips/1575384.jpg
# food-101/images/fish_and_chips/2415245.jpg
# food-101/images/fish_and_chips/305528.jpg
# food-101/images/fish_and_chips/50844.jpg
# food-101/images/fish_and_chips/1611179.jpg
# food-101/images/fish_and_chips/100968.jpg
# food-101/images/fish_and_chips/2863885.jpg
# food-101/images/fish_and_chips/3685961.jpg
# food-101/images/fish_and_chips/963161.jpg
# food-101/images/fish_and_chips/3167151.jpg
# food-101/images/fish_and_chips/3556725.jpg
# food-101/images/fish_and_chips/1524204.jpg
# food-101/images/fish_and_chips/3387911.jpg
# food-101/images/fish_and_chips/3364872.jpg
# food-101/images/fish_and_chips/840156.jpg
# food-101/images/fish_and_chips/3635042.jpg
# food-101/images/fish_and_chips/3711321.jpg
# food-101/images/fish_and_chips/1784894.jpg
# food-101/images/fish_and_chips/209613.jpg
# food-101/images/fish_and_chips/676227.jpg
# food-101/images/fish_and_chips/3534777.jpg
# food-101/images/fish_and_chips/946237.jpg
# food-101/images/fish_and_chips/1487105.jpg
# food-101/images/fish_and_chips/2449067.jpg
# food-101/images/fish_and_chips/861993.jpg
# food-101/images/fish_and_chips/16967.jpg
# food-101/images/fish_and_chips/3780455.jpg
# food-101/images/fish_and_chips/303643.jpg
# food-101/images/fish_and_chips/1566646.jpg
# food-101/images/fish_and_chips/2127356.jpg
# food-101/images/fish_and_chips/475763.jpg
# food-101/images/fish_and_chips/3659706.jpg
# food-101/images/fish_and_chips/712481.jpg
# food-101/images/fish_and_chips/1937483.jpg
# food-101/images/fish_and_chips/2003242.jpg
# food-101/images/fish_and_chips/359280.jpg
# food-101/images/fish_and_chips/2607940.jpg
# food-101/images/fish_and_chips/3787360.jpg
# food-101/images/fish_and_chips/2059508.jpg
# food-101/images/fish_and_chips/3353464.jpg
# food-101/images/fish_and_chips/3511879.jpg
# food-101/images/fish_and_chips/1285225.jpg
# food-101/images/fish_and_chips/1568739.jpg
# food-101/images/fish_and_chips/1988141.jpg
# food-101/images/fish_and_chips/3650902.jpg
# food-101/images/fish_and_chips/2186706.jpg
# food-101/images/fish_and_chips/2841305.jpg
# food-101/images/fish_and_chips/3216823.jpg
# food-101/images/fish_and_chips/2516120.jpg
# food-101/images/fish_and_chips/705141.jpg
# food-101/images/fish_and_chips/1961695.jpg
# food-101/images/fish_and_chips/626746.jpg
# food-101/images/fish_and_chips/1758420.jpg
# food-101/images/fish_and_chips/1860783.jpg
# food-101/images/fish_and_chips/1260846.jpg
# food-101/images/fish_and_chips/2860752.jpg
# food-101/images/fish_and_chips/1249117.jpg
# food-101/images/fish_and_chips/823758.jpg
# food-101/images/fish_and_chips/100703.jpg
# food-101/images/fish_and_chips/875382.jpg
# food-101/images/fish_and_chips/1549845.jpg
# food-101/images/fish_and_chips/3756773.jpg
# food-101/images/fish_and_chips/3188785.jpg
# food-101/images/fish_and_chips/1123342.jpg
# food-101/images/fish_and_chips/1200129.jpg
# food-101/images/fish_and_chips/424363.jpg
# food-101/images/fish_and_chips/756410.jpg
# food-101/images/fish_and_chips/3470365.jpg
# food-101/images/fish_and_chips/81745.jpg
# food-101/images/fish_and_chips/1339349.jpg
# food-101/images/fish_and_chips/2499857.jpg
# food-101/images/fish_and_chips/1072334.jpg
# food-101/images/fish_and_chips/3802890.jpg
# food-101/images/fish_and_chips/2260197.jpg
# food-101/images/fish_and_chips/484647.jpg
# food-101/images/fish_and_chips/509044.jpg
# food-101/images/fish_and_chips/2178261.jpg
# food-101/images/fish_and_chips/2329239.jpg
# food-101/images/fish_and_chips/639436.jpg
# food-101/images/fish_and_chips/3691052.jpg
# food-101/images/fish_and_chips/3031400.jpg
# food-101/images/fish_and_chips/284369.jpg
# food-101/images/fish_and_chips/703028.jpg
# food-101/images/fish_and_chips/2882164.jpg
# food-101/images/fish_and_chips/421373.jpg
# food-101/images/fish_and_chips/773072.jpg
# food-101/images/fish_and_chips/848302.jpg
# food-101/images/fish_and_chips/2479571.jpg
# food-101/images/fish_and_chips/2011865.jpg
# food-101/images/fish_and_chips/2300504.jpg
# food-101/images/fish_and_chips/3394026.jpg
# food-101/images/fish_and_chips/464433.jpg
# food-101/images/fish_and_chips/1542365.jpg
# food-101/images/fish_and_chips/2048255.jpg
# food-101/images/fish_and_chips/439423.jpg
# food-101/images/fish_and_chips/3271526.jpg
# food-101/images/fish_and_chips/1187445.jpg
# food-101/images/fish_and_chips/67185.jpg
# food-101/images/fish_and_chips/2292798.jpg
# food-101/images/fish_and_chips/259347.jpg
# food-101/images/fish_and_chips/1148095.jpg
# food-101/images/fish_and_chips/3757195.jpg
# food-101/images/fish_and_chips/1521651.jpg
# food-101/images/fish_and_chips/3284396.jpg
# food-101/images/fish_and_chips/1195292.jpg
# food-101/images/fish_and_chips/1409809.jpg
# food-101/images/fish_and_chips/2806235.jpg
# food-101/images/fish_and_chips/3174202.jpg
# food-101/images/fish_and_chips/2898571.jpg
# food-101/images/fish_and_chips/2604922.jpg
# food-101/images/fish_and_chips/1275381.jpg
# food-101/images/fish_and_chips/1134522.jpg
# food-101/images/fish_and_chips/1461065.jpg
# food-101/images/fish_and_chips/2425760.jpg
# food-101/images/fish_and_chips/2661907.jpg
# food-101/images/fish_and_chips/312009.jpg
# food-101/images/fish_and_chips/675824.jpg
# food-101/images/fish_and_chips/3469535.jpg
# food-101/images/fish_and_chips/2756991.jpg
# food-101/images/fish_and_chips/1278469.jpg
# food-101/images/fish_and_chips/801805.jpg
# food-101/images/fish_and_chips/1274939.jpg
# food-101/images/fish_and_chips/1189125.jpg
# food-101/images/fish_and_chips/280366.jpg
# food-101/images/fish_and_chips/2852000.jpg
# food-101/images/fish_and_chips/3271369.jpg
# food-101/images/fish_and_chips/452498.jpg
# food-101/images/fish_and_chips/3118637.jpg
# food-101/images/fish_and_chips/2682567.jpg
# food-101/images/fish_and_chips/2652734.jpg
# food-101/images/fish_and_chips/2154878.jpg
# food-101/images/fish_and_chips/701446.jpg
# food-101/images/fish_and_chips/1331356.jpg
# food-101/images/fish_and_chips/1852276.jpg
# food-101/images/fish_and_chips/2672110.jpg
# food-101/images/fish_and_chips/487787.jpg
# food-101/images/fish_and_chips/3174236.jpg
# food-101/images/fish_and_chips/1100346.jpg
# food-101/images/fish_and_chips/969510.jpg
# food-101/images/fish_and_chips/1331770.jpg
# food-101/images/fish_and_chips/3286080.jpg
# food-101/images/fish_and_chips/1886492.jpg
# food-101/images/fish_and_chips/1875602.jpg
# food-101/images/fish_and_chips/907329.jpg
# food-101/images/fish_and_chips/2611467.jpg
# food-101/images/fish_and_chips/1706336.jpg
# food-101/images/fish_and_chips/2196209.jpg
# food-101/images/fish_and_chips/2853767.jpg
# food-101/images/fish_and_chips/1472095.jpg
# food-101/images/fish_and_chips/925849.jpg
# food-101/images/fish_and_chips/456547.jpg
# food-101/images/fish_and_chips/3849709.jpg
# food-101/images/fish_and_chips/97086.jpg
# food-101/images/fish_and_chips/3300571.jpg
# food-101/images/fish_and_chips/535559.jpg
# food-101/images/fish_and_chips/2417745.jpg
# food-101/images/fish_and_chips/3919926.jpg
# food-101/images/fish_and_chips/235908.jpg
# food-101/images/fish_and_chips/2445191.jpg
# food-101/images/fish_and_chips/64762.jpg
# food-101/images/fish_and_chips/1915806.jpg
# food-101/images/fish_and_chips/2402712.jpg
# food-101/images/fish_and_chips/2794555.jpg
# food-101/images/fish_and_chips/448834.jpg
# food-101/images/fish_and_chips/386052.jpg
# food-101/images/fish_and_chips/2586437.jpg
# food-101/images/fish_and_chips/2985503.jpg
# food-101/images/fish_and_chips/1147880.jpg
# food-101/images/fish_and_chips/400102.jpg
# food-101/images/fish_and_chips/2260362.jpg
# food-101/images/fish_and_chips/545313.jpg
# food-101/images/fish_and_chips/3091415.jpg
# food-101/images/fish_and_chips/189837.jpg
# food-101/images/fish_and_chips/654716.jpg
# food-101/images/fish_and_chips/1902449.jpg
# food-101/images/fish_and_chips/807471.jpg
# food-101/images/fish_and_chips/1906888.jpg
# food-101/images/fish_and_chips/3909172.jpg
# food-101/images/fish_and_chips/1422566.jpg
# food-101/images/fish_and_chips/1265554.jpg
# food-101/images/fish_and_chips/557883.jpg
# food-101/images/fish_and_chips/3856147.jpg
# food-101/images/fish_and_chips/1503402.jpg
# food-101/images/fish_and_chips/2292774.jpg
# food-101/images/fish_and_chips/2363485.jpg
# food-101/images/fish_and_chips/1791001.jpg
# food-101/images/fish_and_chips/1811496.jpg
# food-101/images/fish_and_chips/2901529.jpg
# food-101/images/fish_and_chips/3473603.jpg
# food-101/images/fish_and_chips/3923746.jpg
# food-101/images/fish_and_chips/2726225.jpg
# food-101/images/fish_and_chips/781670.jpg
# food-101/images/caesar_salad/
# food-101/images/caesar_salad/2357604.jpg
# food-101/images/caesar_salad/304497.jpg
# food-101/images/caesar_salad/3872022.jpg
# food-101/images/caesar_salad/20940.jpg
# food-101/images/caesar_salad/1489870.jpg
# food-101/images/caesar_salad/2057873.jpg
# food-101/images/caesar_salad/636238.jpg
# food-101/images/caesar_salad/3707137.jpg
# food-101/images/caesar_salad/3118908.jpg
# food-101/images/caesar_salad/151313.jpg
# food-101/images/caesar_salad/2707518.jpg
# food-101/images/caesar_salad/3704650.jpg
# food-101/images/caesar_salad/2162116.jpg
# food-101/images/caesar_salad/550632.jpg
# food-101/images/caesar_salad/1279225.jpg
# food-101/images/caesar_salad/2875241.jpg
# food-101/images/caesar_salad/2290959.jpg
# food-101/images/caesar_salad/3265106.jpg
# food-101/images/caesar_salad/1724480.jpg
# food-101/images/caesar_salad/1655562.jpg
# food-101/images/caesar_salad/1718970.jpg
# food-101/images/caesar_salad/2579080.jpg
# food-101/images/caesar_salad/1817377.jpg
# food-101/images/caesar_salad/2683955.jpg
# food-101/images/caesar_salad/284135.jpg
# food-101/images/caesar_salad/3703325.jpg
# food-101/images/caesar_salad/856005.jpg
# food-101/images/caesar_salad/2916513.jpg
# food-101/images/caesar_salad/2874476.jpg
# food-101/images/caesar_salad/558762.jpg
# food-101/images/caesar_salad/2184085.jpg
# food-101/images/caesar_salad/3737620.jpg
# food-101/images/caesar_salad/211944.jpg
# food-101/images/caesar_salad/3740780.jpg
# food-101/images/caesar_salad/1000435.jpg
# food-101/images/caesar_salad/2780026.jpg
# food-101/images/caesar_salad/455796.jpg
# food-101/images/caesar_salad/2984518.jpg
# food-101/images/caesar_salad/3897011.jpg
# food-101/images/caesar_salad/3824310.jpg
# food-101/images/caesar_salad/1539075.jpg
# food-101/images/caesar_salad/3632320.jpg
# food-101/images/caesar_salad/2801368.jpg
# food-101/images/caesar_salad/3407801.jpg
# food-101/images/caesar_salad/2761224.jpg
# food-101/images/caesar_salad/3370517.jpg
# food-101/images/caesar_salad/2448338.jpg
# food-101/images/caesar_salad/1194996.jpg
# food-101/images/caesar_salad/3010979.jpg
# food-101/images/caesar_salad/515285.jpg
# food-101/images/caesar_salad/2874871.jpg
# food-101/images/caesar_salad/2122717.jpg
# food-101/images/caesar_salad/3716169.jpg
# food-101/images/caesar_salad/517093.jpg
# food-101/images/caesar_salad/1674298.jpg
# food-101/images/caesar_salad/1311466.jpg
# food-101/images/caesar_salad/1517451.jpg
# food-101/images/caesar_salad/734881.jpg
# food-101/images/caesar_salad/1156680.jpg
# food-101/images/caesar_salad/3617220.jpg
# food-101/images/caesar_salad/2010290.jpg
# food-101/images/caesar_salad/2001907.jpg
# food-101/images/caesar_salad/851072.jpg
# food-101/images/caesar_salad/2214485.jpg
# food-101/images/caesar_salad/1368688.jpg
# food-101/images/caesar_salad/3591385.jpg
# food-101/images/caesar_salad/1481015.jpg
# food-101/images/caesar_salad/2018388.jpg
# food-101/images/caesar_salad/728727.jpg
# food-101/images/caesar_salad/2583360.jpg
# food-101/images/caesar_salad/3748534.jpg
# food-101/images/caesar_salad/1433891.jpg
# food-101/images/caesar_salad/1490030.jpg
# food-101/images/caesar_salad/560457.jpg
# food-101/images/caesar_salad/1858738.jpg
# food-101/images/caesar_salad/3315886.jpg
# food-101/images/caesar_salad/3449096.jpg
# food-101/images/caesar_salad/2263243.jpg
# food-101/images/caesar_salad/3471170.jpg
# food-101/images/caesar_salad/2534305.jpg
# food-101/images/caesar_salad/1168972.jpg
# food-101/images/caesar_salad/2213093.jpg
# food-101/images/caesar_salad/3220094.jpg
# food-101/images/caesar_salad/1198449.jpg
# food-101/images/caesar_salad/1053979.jpg
# food-101/images/caesar_salad/2360228.jpg
# food-101/images/caesar_salad/3314255.jpg
# food-101/images/caesar_salad/1534900.jpg
# food-101/images/caesar_salad/2351960.jpg
# food-101/images/caesar_salad/1182436.jpg
# food-101/images/caesar_salad/2939998.jpg
# food-101/images/caesar_salad/2431872.jpg
# food-101/images/caesar_salad/59752.jpg
# food-101/images/caesar_salad/2794828.jpg
# food-101/images/caesar_salad/1814333.jpg
# food-101/images/caesar_salad/2735027.jpg
# food-101/images/caesar_salad/3496239.jpg
# food-101/images/caesar_salad/1092587.jpg
# food-101/images/caesar_salad/432805.jpg
# food-101/images/caesar_salad/3520407.jpg
# food-101/images/caesar_salad/90921.jpg
# food-101/images/caesar_salad/2000894.jpg
# food-101/images/caesar_salad/3828001.jpg
# food-101/images/caesar_salad/3261750.jpg
# food-101/images/caesar_salad/1941951.jpg
# food-101/images/caesar_salad/938204.jpg
# food-101/images/caesar_salad/2039808.jpg
# food-101/images/caesar_salad/629388.jpg
# food-101/images/caesar_salad/2700959.jpg
# food-101/images/caesar_salad/1916135.jpg
# food-101/images/caesar_salad/3655302.jpg
# food-101/images/caesar_salad/674948.jpg
# food-101/images/caesar_salad/2379798.jpg
# food-101/images/caesar_salad/617103.jpg
# food-101/images/caesar_salad/904878.jpg
# food-101/images/caesar_salad/2879188.jpg
# food-101/images/caesar_salad/273429.jpg
# food-101/images/caesar_salad/791462.jpg
# food-101/images/caesar_salad/543547.jpg
# food-101/images/caesar_salad/2029479.jpg
# food-101/images/caesar_salad/1822164.jpg
# food-101/images/caesar_salad/2631000.jpg
# food-101/images/caesar_salad/3269122.jpg
# food-101/images/caesar_salad/2059363.jpg
# food-101/images/caesar_salad/89271.jpg
# food-101/images/caesar_salad/3824196.jpg
# food-101/images/caesar_salad/2401101.jpg
# food-101/images/caesar_salad/2854180.jpg
# food-101/images/caesar_salad/1545902.jpg
# food-101/images/caesar_salad/185911.jpg
# food-101/images/caesar_salad/2161526.jpg
# food-101/images/caesar_salad/2126034.jpg
# food-101/images/caesar_salad/1439476.jpg
# food-101/images/caesar_salad/3327341.jpg
# food-101/images/caesar_salad/2269300.jpg
# food-101/images/caesar_salad/404114.jpg
# food-101/images/caesar_salad/524653.jpg
# food-101/images/caesar_salad/1681647.jpg
# food-101/images/caesar_salad/302309.jpg
# food-101/images/caesar_salad/3004433.jpg
# food-101/images/caesar_salad/3439225.jpg
# food-101/images/caesar_salad/3607351.jpg
# food-101/images/caesar_salad/3823988.jpg
# food-101/images/caesar_salad/3409152.jpg
# food-101/images/caesar_salad/807144.jpg
# food-101/images/caesar_salad/2079096.jpg
# food-101/images/caesar_salad/644717.jpg
# food-101/images/caesar_salad/1665706.jpg
# food-101/images/caesar_salad/1705655.jpg
# food-101/images/caesar_salad/3029541.jpg
# food-101/images/caesar_salad/3386734.jpg
# food-101/images/caesar_salad/1633837.jpg
# food-101/images/caesar_salad/639217.jpg
# food-101/images/caesar_salad/3640443.jpg
# food-101/images/caesar_salad/290295.jpg
# food-101/images/caesar_salad/1618389.jpg
# food-101/images/caesar_salad/3035235.jpg
# food-101/images/caesar_salad/2650771.jpg
# food-101/images/caesar_salad/3467180.jpg
# food-101/images/caesar_salad/325459.jpg
# food-101/images/caesar_salad/3319593.jpg
# food-101/images/caesar_salad/2243810.jpg
# food-101/images/caesar_salad/3775936.jpg
# food-101/images/caesar_salad/209350.jpg
# food-101/images/caesar_salad/3560500.jpg
# food-101/images/caesar_salad/1919297.jpg
# food-101/images/caesar_salad/274409.jpg
# food-101/images/caesar_salad/3210339.jpg
# food-101/images/caesar_salad/290719.jpg
# food-101/images/caesar_salad/1597821.jpg
# food-101/images/caesar_salad/726682.jpg
# food-101/images/caesar_salad/315023.jpg
# food-101/images/caesar_salad/2838115.jpg
# food-101/images/caesar_salad/2281598.jpg
# food-101/images/caesar_salad/2754154.jpg
# food-101/images/caesar_salad/2002164.jpg
# food-101/images/caesar_salad/3600212.jpg
# food-101/images/caesar_salad/2561985.jpg
# food-101/images/caesar_salad/481033.jpg
# food-101/images/caesar_salad/3811878.jpg
# food-101/images/caesar_salad/1427802.jpg
# food-101/images/caesar_salad/3165700.jpg
# food-101/images/caesar_salad/2733135.jpg
# food-101/images/caesar_salad/483942.jpg
# food-101/images/caesar_salad/3374787.jpg
# food-101/images/caesar_salad/1507954.jpg
# food-101/images/caesar_salad/1687999.jpg
# food-101/images/caesar_salad/328441.jpg
# food-101/images/caesar_salad/2758969.jpg
# food-101/images/caesar_salad/1165625.jpg
# food-101/images/caesar_salad/946165.jpg
# food-101/images/caesar_salad/1636130.jpg
# food-101/images/caesar_salad/3623574.jpg
# food-101/images/caesar_salad/3146623.jpg
# food-101/images/caesar_salad/295856.jpg
# food-101/images/caesar_salad/3791298.jpg
# food-101/images/caesar_salad/3512052.jpg
# food-101/images/caesar_salad/972863.jpg
# food-101/images/caesar_salad/2790337.jpg
# food-101/images/caesar_salad/1638624.jpg
# food-101/images/caesar_salad/2431467.jpg
# food-101/images/caesar_salad/2322354.jpg
# food-101/images/caesar_salad/3018574.jpg
# food-101/images/caesar_salad/3086337.jpg
# food-101/images/caesar_salad/1186415.jpg
# food-101/images/caesar_salad/3659545.jpg
# food-101/images/caesar_salad/560093.jpg
# food-101/images/caesar_salad/1505913.jpg
# food-101/images/caesar_salad/2581326.jpg
# food-101/images/caesar_salad/747482.jpg
# food-101/images/caesar_salad/2425381.jpg
# food-101/images/caesar_salad/1406418.jpg
# food-101/images/caesar_salad/849754.jpg
# food-101/images/caesar_salad/3190754.jpg
# food-101/images/caesar_salad/727976.jpg
# food-101/images/caesar_salad/3637443.jpg
# food-101/images/caesar_salad/2667246.jpg
# food-101/images/caesar_salad/1316473.jpg
# food-101/images/caesar_salad/2109508.jpg
# food-101/images/caesar_salad/3233214.jpg
# food-101/images/caesar_salad/3592217.jpg
# food-101/images/caesar_salad/498492.jpg
# food-101/images/caesar_salad/1801898.jpg
# food-101/images/caesar_salad/3824099.jpg
# food-101/images/caesar_salad/3374324.jpg
# food-101/images/caesar_salad/3845880.jpg
# food-101/images/caesar_salad/2306710.jpg
# food-101/images/caesar_salad/2506752.jpg
# food-101/images/caesar_salad/3188150.jpg
# food-101/images/caesar_salad/1169831.jpg
# food-101/images/caesar_salad/960681.jpg
# food-101/images/caesar_salad/1727463.jpg
# food-101/images/caesar_salad/1348253.jpg
# food-101/images/caesar_salad/1766457.jpg
# food-101/images/caesar_salad/1684239.jpg
# food-101/images/caesar_salad/1909071.jpg
# food-101/images/caesar_salad/3274011.jpg
# food-101/images/caesar_salad/832298.jpg
# food-101/images/caesar_salad/1097603.jpg
# food-101/images/caesar_salad/2050496.jpg
# food-101/images/caesar_salad/1176809.jpg
# food-101/images/caesar_salad/2013029.jpg
# food-101/images/caesar_salad/2617305.jpg
# food-101/images/caesar_salad/1793799.jpg
# food-101/images/caesar_salad/3534832.jpg
# food-101/images/caesar_salad/2739909.jpg
# food-101/images/caesar_salad/2919810.jpg
# food-101/images/caesar_salad/3138677.jpg
# food-101/images/caesar_salad/2129206.jpg
# food-101/images/caesar_salad/1175434.jpg
# food-101/images/caesar_salad/1493566.jpg
# food-101/images/caesar_salad/707891.jpg
# food-101/images/caesar_salad/2415567.jpg
# food-101/images/caesar_salad/976488.jpg
# food-101/images/caesar_salad/1898389.jpg
# food-101/images/caesar_salad/3798145.jpg
# food-101/images/caesar_salad/3912473.jpg
# food-101/images/caesar_salad/2626210.jpg
# food-101/images/caesar_salad/658026.jpg
# food-101/images/caesar_salad/147653.jpg
# food-101/images/caesar_salad/3158516.jpg
# food-101/images/caesar_salad/3311499.jpg
# food-101/images/caesar_salad/1798525.jpg
# food-101/images/caesar_salad/3269561.jpg
# food-101/images/caesar_salad/3697059.jpg
# food-101/images/caesar_salad/88048.jpg
# food-101/images/caesar_salad/2150887.jpg
# food-101/images/caesar_salad/196112.jpg
# food-101/images/caesar_salad/3371819.jpg
# food-101/images/caesar_salad/2354912.jpg
# food-101/images/caesar_salad/1651408.jpg
# food-101/images/caesar_salad/2278244.jpg
# food-101/images/caesar_salad/3764734.jpg
# food-101/images/caesar_salad/3614125.jpg
# food-101/images/caesar_salad/3412723.jpg
# food-101/images/caesar_salad/3041196.jpg
# food-101/images/caesar_salad/1721699.jpg
# food-101/images/caesar_salad/1657139.jpg
# food-101/images/caesar_salad/2521424.jpg
# food-101/images/caesar_salad/1226429.jpg
# food-101/images/caesar_salad/2735104.jpg
# food-101/images/caesar_salad/1921911.jpg
# food-101/images/caesar_salad/540853.jpg
# food-101/images/caesar_salad/3496346.jpg
# food-101/images/caesar_salad/2910283.jpg
# food-101/images/caesar_salad/1275421.jpg
# food-101/images/caesar_salad/3362823.jpg
# food-101/images/caesar_salad/437710.jpg
# food-101/images/caesar_salad/1635167.jpg
# food-101/images/caesar_salad/868705.jpg
# food-101/images/caesar_salad/2751304.jpg
# food-101/images/caesar_salad/788257.jpg
# food-101/images/caesar_salad/2524196.jpg
# food-101/images/caesar_salad/2784457.jpg
# food-101/images/caesar_salad/70283.jpg
# food-101/images/caesar_salad/1600903.jpg
# food-101/images/caesar_salad/2895075.jpg
# food-101/images/caesar_salad/80211.jpg
# food-101/images/caesar_salad/3485044.jpg
# food-101/images/caesar_salad/337884.jpg
# food-101/images/caesar_salad/1399346.jpg
# food-101/images/caesar_salad/789194.jpg
# food-101/images/caesar_salad/2442562.jpg
# food-101/images/caesar_salad/504752.jpg
# food-101/images/caesar_salad/98656.jpg
# food-101/images/caesar_salad/680811.jpg
# food-101/images/caesar_salad/886181.jpg
# food-101/images/caesar_salad/2110393.jpg
# food-101/images/caesar_salad/277148.jpg
# food-101/images/caesar_salad/1565576.jpg
# food-101/images/caesar_salad/1013504.jpg
# food-101/images/caesar_salad/1645259.jpg
# food-101/images/caesar_salad/3456502.jpg
# food-101/images/caesar_salad/1835043.jpg
# food-101/images/caesar_salad/141795.jpg
# food-101/images/caesar_salad/2937979.jpg
# food-101/images/caesar_salad/1853841.jpg
# food-101/images/caesar_salad/3113021.jpg
# food-101/images/caesar_salad/826876.jpg
# food-101/images/caesar_salad/2517125.jpg
# food-101/images/caesar_salad/263620.jpg
# food-101/images/caesar_salad/1262561.jpg
# food-101/images/caesar_salad/2302637.jpg
# food-101/images/caesar_salad/2911058.jpg
# food-101/images/caesar_salad/3525537.jpg
# food-101/images/caesar_salad/5658.jpg
# food-101/images/caesar_salad/199565.jpg
# food-101/images/caesar_salad/1884208.jpg
# food-101/images/caesar_salad/1617779.jpg
# food-101/images/caesar_salad/2229672.jpg
# food-101/images/caesar_salad/1762442.jpg
# food-101/images/caesar_salad/2415458.jpg
# food-101/images/caesar_salad/3234477.jpg
# food-101/images/caesar_salad/2599756.jpg
# food-101/images/caesar_salad/2412264.jpg
# food-101/images/caesar_salad/2942731.jpg
# food-101/images/caesar_salad/2489810.jpg
# food-101/images/caesar_salad/2937030.jpg
# food-101/images/caesar_salad/2077011.jpg
# food-101/images/caesar_salad/2967593.jpg
# food-101/images/caesar_salad/869919.jpg
# food-101/images/caesar_salad/2240630.jpg
# food-101/images/caesar_salad/2758085.jpg
# food-101/images/caesar_salad/1058139.jpg
# food-101/images/caesar_salad/820057.jpg
# food-101/images/caesar_salad/148869.jpg
# food-101/images/caesar_salad/1960668.jpg
# food-101/images/caesar_salad/1887671.jpg
# food-101/images/caesar_salad/2157527.jpg
# food-101/images/caesar_salad/3021520.jpg
# food-101/images/caesar_salad/3466736.jpg
# food-101/images/caesar_salad/2877666.jpg
# food-101/images/caesar_salad/1368866.jpg
# food-101/images/caesar_salad/1146669.jpg
# food-101/images/caesar_salad/1707324.jpg
# food-101/images/caesar_salad/3327301.jpg
# food-101/images/caesar_salad/2349539.jpg
# food-101/images/caesar_salad/902374.jpg
# food-101/images/caesar_salad/2228238.jpg
# food-101/images/caesar_salad/2559446.jpg
# food-101/images/caesar_salad/2418102.jpg
# food-101/images/caesar_salad/3423512.jpg
# food-101/images/caesar_salad/1369936.jpg
# food-101/images/caesar_salad/1834141.jpg
# food-101/images/caesar_salad/2781242.jpg
# food-101/images/caesar_salad/1855617.jpg
# food-101/images/caesar_salad/2850277.jpg
# food-101/images/caesar_salad/2151978.jpg
# food-101/images/caesar_salad/3660328.jpg
# food-101/images/caesar_salad/2212741.jpg
# food-101/images/caesar_salad/648670.jpg
# food-101/images/caesar_salad/3236889.jpg
# food-101/images/caesar_salad/814439.jpg
# food-101/images/caesar_salad/2728974.jpg
# food-101/images/caesar_salad/474292.jpg
# food-101/images/caesar_salad/2909626.jpg
# food-101/images/caesar_salad/1489598.jpg
# food-101/images/caesar_salad/3668460.jpg
# food-101/images/caesar_salad/569231.jpg
# food-101/images/caesar_salad/3759187.jpg
# food-101/images/caesar_salad/240649.jpg
# food-101/images/caesar_salad/804387.jpg
# food-101/images/caesar_salad/1260222.jpg
# food-101/images/caesar_salad/2874677.jpg
# food-101/images/caesar_salad/513381.jpg
# food-101/images/caesar_salad/2710652.jpg
# food-101/images/caesar_salad/3228048.jpg
# food-101/images/caesar_salad/1480826.jpg
# food-101/images/caesar_salad/3289797.jpg
# food-101/images/caesar_salad/3744588.jpg
# food-101/images/caesar_salad/27165.jpg
# food-101/images/caesar_salad/2055428.jpg
# food-101/images/caesar_salad/2627557.jpg
# food-101/images/caesar_salad/509901.jpg
# food-101/images/caesar_salad/1226917.jpg
# food-101/images/caesar_salad/126205.jpg
# food-101/images/caesar_salad/267740.jpg
# food-101/images/caesar_salad/56013.jpg
# food-101/images/caesar_salad/2498776.jpg
# food-101/images/caesar_salad/141784.jpg
# food-101/images/caesar_salad/3712546.jpg
# food-101/images/caesar_salad/2978581.jpg
# food-101/images/caesar_salad/1627608.jpg
# food-101/images/caesar_salad/1622045.jpg
# food-101/images/caesar_salad/2229474.jpg
# food-101/images/caesar_salad/2758286.jpg
# food-101/images/caesar_salad/1824467.jpg
# food-101/images/caesar_salad/3728065.jpg
# food-101/images/caesar_salad/416903.jpg
# food-101/images/caesar_salad/615544.jpg
# food-101/images/caesar_salad/3794897.jpg
# food-101/images/caesar_salad/3655567.jpg
# food-101/images/caesar_salad/1878800.jpg
# food-101/images/caesar_salad/1994771.jpg
# food-101/images/caesar_salad/2203330.jpg
# food-101/images/caesar_salad/150152.jpg
# food-101/images/caesar_salad/2771681.jpg
# food-101/images/caesar_salad/3678292.jpg
# food-101/images/caesar_salad/1525278.jpg
# food-101/images/caesar_salad/2949157.jpg
# food-101/images/caesar_salad/2546478.jpg
# food-101/images/caesar_salad/239163.jpg
# food-101/images/caesar_salad/1700074.jpg
# food-101/images/caesar_salad/3578391.jpg
# food-101/images/caesar_salad/3488492.jpg
# food-101/images/caesar_salad/1904729.jpg
# food-101/images/caesar_salad/682984.jpg
# food-101/images/caesar_salad/75835.jpg
# food-101/images/caesar_salad/3859202.jpg
# food-101/images/caesar_salad/1485495.jpg
# food-101/images/caesar_salad/216265.jpg
# food-101/images/caesar_salad/3257917.jpg
# food-101/images/caesar_salad/2176445.jpg
# food-101/images/caesar_salad/1694973.jpg
# food-101/images/caesar_salad/3882063.jpg
# food-101/images/caesar_salad/3265110.jpg
# food-101/images/caesar_salad/2799461.jpg
# food-101/images/caesar_salad/3246252.jpg
# food-101/images/caesar_salad/903843.jpg
# food-101/images/caesar_salad/823016.jpg
# food-101/images/caesar_salad/2935603.jpg
# food-101/images/caesar_salad/2516526.jpg
# food-101/images/caesar_salad/1997625.jpg
# food-101/images/caesar_salad/3373492.jpg
# food-101/images/caesar_salad/387912.jpg
# food-101/images/caesar_salad/1182817.jpg
# food-101/images/caesar_salad/2181670.jpg
# ...
# food-101/images/chocolate_mousse/1151565.jpg
# food-101/images/chocolate_mousse/2495604.jpg
# food-101/images/chocolate_mousse/2512808.jpg
# food-101/images/chocolate_mousse/3198946.jpg
# food-101/images/chocolate_mousse/906657.jpg
# food-101/images/chocolate_mousse/3890174.jpg
# food-101/images/chocolate_mousse/2758766.jpg
# food-101/images/chocolate_mousse/183889.jpg
# food-101/images/chocolate_mousse/3248977.jpg
# food-101/images/chocolate_mousse/2594940.jpg
# food-101/images/chocolate_mousse/3072098.jpg
# food-101/images/chocolate_mousse/2900520.jpg
# food-101/images/chocolate_mousse/2386973.jpg
# food-101/images/chocolate_mousse/328362.jpg
# food-101/images/chocolate_mousse/2334692.jpg
# food-101/images/chocolate_mousse/893495.jpg
# food-101/images/chocolate_mousse/1977294.jpg
# food-101/images/chocolate_mousse/3057195.jpg
# food-101/images/chocolate_mousse/1876213.jpg
# food-101/images/chocolate_mousse/2235289.jpg
# food-101/images/chocolate_mousse/3454791.jpg
# food-101/images/chocolate_mousse/3829597.jpg
# food-101/images/chocolate_mousse/1146332.jpg
# food-101/images/chocolate_mousse/2935942.jpg
# food-101/images/chocolate_mousse/3639891.jpg
# food-101/images/chocolate_mousse/1987701.jpg
# food-101/images/chocolate_mousse/1186930.jpg
# food-101/images/chocolate_mousse/2571028.jpg
# food-101/images/chocolate_mousse/745911.jpg
# food-101/images/chocolate_mousse/1861259.jpg
# food-101/images/chocolate_mousse/2433868.jpg
# food-101/images/chocolate_mousse/2993358.jpg
# food-101/images/chocolate_mousse/3017757.jpg
# food-101/images/chocolate_mousse/2175584.jpg
# food-101/images/chocolate_mousse/1667209.jpg
# food-101/images/chocolate_mousse/1622112.jpg
# food-101/images/chocolate_mousse/3321965.jpg
# food-101/images/chocolate_mousse/1062490.jpg
# food-101/images/chocolate_mousse/3346125.jpg
# food-101/images/chocolate_mousse/1489511.jpg
# food-101/images/chocolate_mousse/3025293.jpg
# food-101/images/chocolate_mousse/750083.jpg
# food-101/images/chocolate_mousse/1752475.jpg
# food-101/images/chocolate_mousse/455627.jpg
# food-101/images/chocolate_mousse/2456517.jpg
# food-101/images/chocolate_mousse/2453984.jpg
# food-101/images/chocolate_mousse/2374973.jpg
# food-101/images/chocolate_mousse/779775.jpg
# food-101/images/chocolate_mousse/2419236.jpg
# food-101/images/chocolate_mousse/472088.jpg
# food-101/images/chocolate_mousse/416688.jpg
# food-101/images/chocolate_mousse/130070.jpg
# food-101/images/chocolate_mousse/2539049.jpg
# food-101/images/chocolate_mousse/3346226.jpg
# food-101/images/chocolate_mousse/3546527.jpg
# food-101/images/chocolate_mousse/2188987.jpg
# food-101/images/chocolate_mousse/3002014.jpg
# food-101/images/chocolate_mousse/2870385.jpg
# food-101/images/chocolate_mousse/1206320.jpg
# food-101/images/chocolate_mousse/2534186.jpg
# food-101/images/chocolate_mousse/3227227.jpg
# food-101/images/chocolate_mousse/3544099.jpg
# food-101/images/chocolate_mousse/3774024.jpg
# food-101/images/chocolate_mousse/2097972.jpg
# food-101/images/chocolate_mousse/1605957.jpg
# food-101/images/chocolate_mousse/2174774.jpg
# food-101/images/chocolate_mousse/3453019.jpg
# food-101/images/chocolate_mousse/2540254.jpg
# food-101/images/chocolate_mousse/1381813.jpg
# food-101/images/chocolate_mousse/3914362.jpg
# food-101/images/chocolate_mousse/2324758.jpg
# food-101/images/chocolate_mousse/828774.jpg
# food-101/images/chocolate_mousse/252250.jpg
# food-101/images/chocolate_mousse/3319481.jpg
# food-101/images/chocolate_mousse/640.jpg
# food-101/images/chocolate_mousse/3511892.jpg
# food-101/images/chocolate_mousse/2171145.jpg
# food-101/images/chocolate_mousse/3664420.jpg
# food-101/images/chocolate_mousse/940054.jpg
# food-101/images/chocolate_mousse/3747404.jpg
# food-101/images/chocolate_mousse/2310232.jpg
# food-101/images/chocolate_mousse/505057.jpg
# food-101/images/chocolate_mousse/87225.jpg
# food-101/images/chocolate_mousse/1983625.jpg
# food-101/images/chocolate_mousse/3251796.jpg
# food-101/images/chocolate_mousse/135385.jpg
# food-101/images/chocolate_mousse/781270.jpg
# food-101/images/chocolate_mousse/2185548.jpg
# food-101/images/chocolate_mousse/1357498.jpg
# food-101/images/chocolate_mousse/452179.jpg
# food-101/images/chocolate_mousse/586107.jpg
# food-101/images/chocolate_mousse/3307843.jpg
# food-101/images/chocolate_mousse/593572.jpg
# food-101/images/chocolate_mousse/742697.jpg
# food-101/images/chocolate_mousse/106928.jpg
# food-101/images/chocolate_mousse/1582076.jpg
# food-101/images/chocolate_mousse/2892884.jpg
# food-101/images/chocolate_mousse/3129230.jpg
# food-101/images/chocolate_mousse/1238159.jpg
# food-101/images/chocolate_mousse/1508926.jpg
# food-101/images/chocolate_mousse/2372123.jpg
# food-101/images/chocolate_mousse/1793072.jpg
# food-101/images/chocolate_mousse/2250553.jpg
# food-101/images/chocolate_mousse/2286616.jpg
# food-101/images/chocolate_mousse/2746903.jpg
# food-101/images/chocolate_mousse/1993513.jpg
# food-101/images/chocolate_mousse/3713764.jpg
# food-101/images/chocolate_mousse/1045302.jpg
# food-101/images/chocolate_mousse/1501198.jpg
# food-101/images/chocolate_mousse/1649877.jpg
# food-101/images/chocolate_mousse/3474532.jpg
# food-101/images/chocolate_mousse/3395680.jpg
# food-101/images/chocolate_mousse/177076.jpg
# food-101/images/chocolate_mousse/2659365.jpg
# food-101/images/chocolate_mousse/3887915.jpg
# food-101/images/chocolate_mousse/365572.jpg
# food-101/images/chocolate_mousse/1277545.jpg
# food-101/images/chocolate_mousse/3499162.jpg
# food-101/images/lasagna/
# food-101/images/lasagna/893356.jpg
# food-101/images/lasagna/1166813.jpg
# food-101/images/lasagna/1552394.jpg
# food-101/images/lasagna/2213727.jpg
# food-101/images/lasagna/2589799.jpg
# food-101/images/lasagna/2876355.jpg
# food-101/images/lasagna/2399534.jpg
# food-101/images/lasagna/2592460.jpg
# food-101/images/lasagna/2160855.jpg
# food-101/images/lasagna/1833706.jpg
# food-101/images/lasagna/826119.jpg
# food-101/images/lasagna/2547580.jpg
# food-101/images/lasagna/2878288.jpg
# food-101/images/lasagna/3824613.jpg
# food-101/images/lasagna/1298150.jpg
# food-101/images/lasagna/2201056.jpg
# food-101/images/lasagna/3526414.jpg
# food-101/images/lasagna/349190.jpg
# food-101/images/lasagna/3566595.jpg
# food-101/images/lasagna/1151815.jpg
# food-101/images/lasagna/3766418.jpg
# food-101/images/lasagna/1599468.jpg
# food-101/images/lasagna/860471.jpg
# food-101/images/lasagna/323391.jpg
# food-101/images/lasagna/2988456.jpg
# food-101/images/lasagna/158809.jpg
# food-101/images/lasagna/3309388.jpg
# food-101/images/lasagna/3173507.jpg
# food-101/images/lasagna/3470406.jpg
# food-101/images/lasagna/2807131.jpg
# food-101/images/lasagna/2142853.jpg
# food-101/images/lasagna/680566.jpg
# food-101/images/lasagna/3848032.jpg
# food-101/images/lasagna/3413342.jpg
# food-101/images/lasagna/2553517.jpg
# food-101/images/lasagna/3044852.jpg
# food-101/images/lasagna/1385888.jpg
# food-101/images/lasagna/3853715.jpg
# food-101/images/lasagna/1890116.jpg
# food-101/images/lasagna/3232616.jpg
# food-101/images/lasagna/1887343.jpg
# food-101/images/lasagna/1951716.jpg
# food-101/images/lasagna/2055421.jpg
# food-101/images/lasagna/3902158.jpg
# food-101/images/lasagna/1708041.jpg
# food-101/images/lasagna/1423956.jpg
# food-101/images/lasagna/968790.jpg
# food-101/images/lasagna/2930738.jpg
# food-101/images/lasagna/2188986.jpg
# food-101/images/lasagna/3017550.jpg
# food-101/images/lasagna/2696014.jpg
# food-101/images/lasagna/1713884.jpg
# food-101/images/lasagna/1156225.jpg
# food-101/images/lasagna/3731267.jpg
# food-101/images/lasagna/3575597.jpg
# food-101/images/lasagna/2048823.jpg
# food-101/images/lasagna/2555366.jpg
# food-101/images/lasagna/1501581.jpg
# food-101/images/lasagna/3845825.jpg
# food-101/images/lasagna/3216799.jpg
# food-101/images/lasagna/499765.jpg
# food-101/images/lasagna/3648992.jpg
# food-101/images/lasagna/3744490.jpg
# food-101/images/lasagna/325149.jpg
# food-101/images/lasagna/1153290.jpg
# food-101/images/lasagna/3786952.jpg
# food-101/images/lasagna/2606919.jpg
# food-101/images/lasagna/2471803.jpg
# food-101/images/lasagna/2979554.jpg
# food-101/images/lasagna/467131.jpg
# food-101/images/lasagna/1621340.jpg
# food-101/images/lasagna/1729580.jpg
# food-101/images/lasagna/3355549.jpg
# food-101/images/lasagna/553332.jpg
# food-101/images/lasagna/55800.jpg
# food-101/images/lasagna/3607924.jpg
# food-101/images/lasagna/3327789.jpg
# food-101/images/lasagna/3092646.jpg
# food-101/images/lasagna/3489486.jpg
# food-101/images/lasagna/772991.jpg
# food-101/images/lasagna/2335657.jpg
# food-101/images/lasagna/1913289.jpg
# food-101/images/lasagna/3383678.jpg
# food-101/images/lasagna/130442.jpg
# food-101/images/lasagna/1741625.jpg
# food-101/images/lasagna/3434218.jpg
# food-101/images/lasagna/3679026.jpg
# food-101/images/lasagna/731047.jpg
# food-101/images/lasagna/3547438.jpg
# food-101/images/lasagna/3703539.jpg
# food-101/images/lasagna/2613354.jpg
# food-101/images/lasagna/3386685.jpg
# food-101/images/lasagna/1379155.jpg
# food-101/images/lasagna/2434148.jpg
# food-101/images/lasagna/1555213.jpg
# food-101/images/lasagna/531075.jpg
# food-101/images/lasagna/3488510.jpg
# food-101/images/lasagna/2467378.jpg
# food-101/images/lasagna/2259701.jpg
# food-101/images/lasagna/1984893.jpg
# food-101/images/lasagna/1452732.jpg
# food-101/images/lasagna/2075525.jpg
# food-101/images/lasagna/3027390.jpg
# food-101/images/lasagna/2200176.jpg
# food-101/images/lasagna/2972224.jpg
# food-101/images/lasagna/357123.jpg
# food-101/images/lasagna/198015.jpg
# food-101/images/lasagna/1099431.jpg
# food-101/images/lasagna/394593.jpg
# food-101/images/lasagna/3261672.jpg
# food-101/images/lasagna/3264809.jpg
# food-101/images/lasagna/3274820.jpg
# food-101/images/lasagna/3285210.jpg
# food-101/images/lasagna/1481081.jpg
# food-101/images/lasagna/1522717.jpg
# food-101/images/lasagna/3086634.jpg
# food-101/images/lasagna/2218092.jpg
# food-101/images/lasagna/2481780.jpg
# food-101/images/lasagna/3778453.jpg
# food-101/images/lasagna/2552597.jpg
# food-101/images/lasagna/2386254.jpg
# food-101/images/lasagna/3504108.jpg
# food-101/images/lasagna/3129612.jpg
# food-101/images/lasagna/2067586.jpg
# food-101/images/lasagna/3158812.jpg
# food-101/images/lasagna/1829483.jpg
# food-101/images/lasagna/1534964.jpg
# food-101/images/lasagna/1709850.jpg
# food-101/images/lasagna/1005119.jpg
# food-101/images/lasagna/645073.jpg
# food-101/images/lasagna/3607950.jpg
# food-101/images/lasagna/3135514.jpg
# food-101/images/lasagna/3756697.jpg
# food-101/images/lasagna/2936736.jpg
# food-101/images/lasagna/1140060.jpg
# food-101/images/lasagna/2312908.jpg
# food-101/images/lasagna/3873583.jpg
# food-101/images/lasagna/216613.jpg
# food-101/images/lasagna/3066871.jpg
# food-101/images/lasagna/3595714.jpg
# food-101/images/lasagna/2399240.jpg
# food-101/images/lasagna/3446431.jpg
# food-101/images/lasagna/458484.jpg
# food-101/images/lasagna/2827666.jpg
# food-101/images/lasagna/142455.jpg
# food-101/images/lasagna/3259377.jpg
# food-101/images/lasagna/1595219.jpg
# food-101/images/lasagna/725549.jpg
# food-101/images/lasagna/3536808.jpg
# food-101/images/lasagna/2269356.jpg
# food-101/images/lasagna/3150494.jpg
# food-101/images/lasagna/2225010.jpg
# food-101/images/lasagna/2163547.jpg
# food-101/images/lasagna/1178768.jpg
# food-101/images/lasagna/517404.jpg
# food-101/images/lasagna/1670139.jpg
# food-101/images/lasagna/1142842.jpg
# food-101/images/lasagna/2296176.jpg
# food-101/images/lasagna/2710704.jpg
# food-101/images/lasagna/1415468.jpg
# food-101/images/lasagna/3277163.jpg
# food-101/images/lasagna/2570837.jpg
# food-101/images/lasagna/3514299.jpg
# food-101/images/lasagna/2878260.jpg
# food-101/images/lasagna/2721326.jpg
# food-101/images/lasagna/134578.jpg
# food-101/images/lasagna/186602.jpg
# food-101/images/lasagna/3098534.jpg
# food-101/images/lasagna/1131940.jpg
# food-101/images/lasagna/2861857.jpg
# food-101/images/lasagna/3545755.jpg
# food-101/images/lasagna/2399575.jpg
# food-101/images/lasagna/635962.jpg
# food-101/images/lasagna/788117.jpg
# food-101/images/lasagna/2828941.jpg
# food-101/images/lasagna/2808835.jpg
# food-101/images/lasagna/2041726.jpg
# food-101/images/lasagna/3510317.jpg
# food-101/images/lasagna/3124006.jpg
# food-101/images/lasagna/1664062.jpg
# food-101/images/lasagna/3874120.jpg
# food-101/images/lasagna/1737120.jpg
# food-101/images/lasagna/3254622.jpg
# food-101/images/lasagna/2279227.jpg
# food-101/images/lasagna/1713927.jpg
# food-101/images/lasagna/2684083.jpg
# food-101/images/lasagna/2579540.jpg
# food-101/images/lasagna/3559830.jpg
# food-101/images/lasagna/385222.jpg
# food-101/images/lasagna/1641829.jpg
# food-101/images/lasagna/2004491.jpg
# food-101/images/lasagna/1971499.jpg
# food-101/images/lasagna/3474024.jpg
# food-101/images/lasagna/2947822.jpg
# food-101/images/lasagna/2594735.jpg
# food-101/images/lasagna/3303039.jpg
# food-101/images/lasagna/2242849.jpg
# food-101/images/lasagna/1933616.jpg
# food-101/images/lasagna/844507.jpg
# food-101/images/lasagna/3682447.jpg
# food-101/images/lasagna/2150058.jpg
# food-101/images/lasagna/18140.jpg
# food-101/images/lasagna/8959.jpg
# food-101/images/lasagna/806245.jpg
# food-101/images/lasagna/573555.jpg
# food-101/images/lasagna/3440282.jpg
# food-101/images/lasagna/2733142.jpg
# food-101/images/lasagna/3808454.jpg
# food-101/images/lasagna/2125241.jpg
# food-101/images/lasagna/3158734.jpg
# food-101/images/lasagna/1309938.jpg
# food-101/images/lasagna/2221894.jpg
# food-101/images/lasagna/458335.jpg
# food-101/images/lasagna/2920545.jpg
# food-101/images/lasagna/2136041.jpg
# food-101/images/lasagna/3886880.jpg
# food-101/images/lasagna/3038573.jpg
# food-101/images/lasagna/1913263.jpg
# food-101/images/lasagna/3063344.jpg
# food-101/images/lasagna/1134644.jpg
# food-101/images/lasagna/2708694.jpg
# food-101/images/lasagna/2655157.jpg
# food-101/images/lasagna/235304.jpg
# food-101/images/lasagna/2440583.jpg
# food-101/images/lasagna/7781.jpg
# food-101/images/lasagna/2822696.jpg
# food-101/images/lasagna/763059.jpg
# food-101/images/lasagna/1351736.jpg
# food-101/images/lasagna/518253.jpg
# food-101/images/lasagna/2048798.jpg
# food-101/images/lasagna/3819753.jpg
# food-101/images/lasagna/1977275.jpg
# food-101/images/lasagna/2148478.jpg
# food-101/images/lasagna/159612.jpg
# food-101/images/lasagna/3476066.jpg
# food-101/images/lasagna/3238015.jpg
# food-101/images/lasagna/687391.jpg
# food-101/images/lasagna/3493077.jpg
# food-101/images/lasagna/3380510.jpg
# food-101/images/lasagna/693777.jpg
# food-101/images/lasagna/2013208.jpg
# food-101/images/lasagna/2410148.jpg
# food-101/images/lasagna/3386444.jpg
# food-101/images/lasagna/1985079.jpg
# food-101/images/lasagna/2931816.jpg
# food-101/images/lasagna/365521.jpg
# food-101/images/lasagna/734082.jpg
# food-101/images/lasagna/3261920.jpg
# food-101/images/lasagna/1955342.jpg
# food-101/images/lasagna/1853345.jpg
# food-101/images/lasagna/1147397.jpg
# food-101/images/lasagna/1776728.jpg
# food-101/images/lasagna/1152091.jpg
# food-101/images/lasagna/3156158.jpg
# food-101/images/lasagna/3532760.jpg
# food-101/images/lasagna/2597245.jpg
# food-101/images/lasagna/1413539.jpg
# food-101/images/lasagna/1214362.jpg
# food-101/images/lasagna/3581253.jpg
# food-101/images/lasagna/1538138.jpg
# food-101/images/lasagna/3098735.jpg
# food-101/images/lasagna/3717740.jpg
# food-101/images/lasagna/1734910.jpg
# food-101/images/lasagna/2626946.jpg
# food-101/images/lasagna/3468941.jpg
# food-101/images/lasagna/2346118.jpg
# food-101/images/lasagna/1365338.jpg
# food-101/images/lasagna/695181.jpg
# food-101/images/lasagna/2566388.jpg
# food-101/images/lasagna/2654161.jpg
# food-101/images/lasagna/1015789.jpg
# food-101/images/lasagna/2415041.jpg
# food-101/images/lasagna/682652.jpg
# food-101/images/lasagna/1450089.jpg
# food-101/images/lasagna/3314569.jpg
# food-101/images/lasagna/976466.jpg
# food-101/images/lasagna/3353211.jpg
# food-101/images/lasagna/797538.jpg
# food-101/images/lasagna/1952383.jpg
# food-101/images/lasagna/3450966.jpg
# food-101/images/lasagna/340639.jpg
# food-101/images/lasagna/1649861.jpg
# food-101/images/lasagna/2529351.jpg
# food-101/images/lasagna/3006166.jpg
# food-101/images/lasagna/2990708.jpg
# food-101/images/lasagna/3058225.jpg
# food-101/images/lasagna/1820215.jpg
# food-101/images/lasagna/318954.jpg
# food-101/images/lasagna/457804.jpg
# food-101/images/lasagna/1872186.jpg
# food-101/images/lasagna/883328.jpg
# food-101/images/lasagna/1028961.jpg
# food-101/images/lasagna/179621.jpg
# food-101/images/lasagna/3304220.jpg
#
# gzip: stdin: unexpected end of file
# tar: Unexpected EOF in archive
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now

# %% [markdown]
# Step 2: Prepare data generators using file lists

# %%
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Set paths
base_dir = 'food-101'
images_dir = os.path.join(base_dir, 'images')
meta_dir = os.path.join(base_dir, 'meta')

# Read train/test splits
with open(os.path.join(meta_dir, 'train.txt')) as f:
    train_files = [line.strip() for line in f]

with open(os.path.join(meta_dir, 'test.txt')) as f:
    test_files = [line.strip() for line in f]

# Create a helper function to copy files to folders readable by flow_from_directory (optional)
import shutil
def organize_dataset(file_list, target_root):
    for file in file_list:
        class_name = file.split('/')[0]
        src = os.path.join(images_dir, file + '.jpg')
        dst_dir = os.path.join(target_root, class_name)
        os.makedirs(dst_dir, exist_ok=True)
        shutil.copy(src, dst_dir)

# Optional: Organize into train/ and test/ folders
os.makedirs('data/train', exist_ok=True)
os.makedirs('data/test', exist_ok=True)

organize_dataset(train_files, 'data/train')
organize_dataset(test_files, 'data/test')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2907446978.py in <cell line: 0>()
#       8
#       9 # Read train/test splits
# ---> 10 with open(os.path.join(meta_dir, 'train.txt')) as f:
#      11     train_files = [line.strip() for line in f]
#      12
#
# FileNotFoundError: [Errno 2] No such file or directory: 'food-101/meta/train.txt'

# %% [markdown]
# Step 3: Use Keras ImageDataGenerator to load the images

# %%
import pathlib

data_dir = pathlib.Path("data/train")
test_dir = pathlib.Path("data/test")

batch_size = 32
img_size = (224, 224)


train_dataset = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    image_size=img_size,
    batch_size=batch_size,
    label_mode="categorical",  # for categorical_crossentropy
    shuffle=True,
    seed=42
)

test_dataset = tf.keras.utils.image_dataset_from_directory(
    test_dir,
    image_size=img_size,
    batch_size=batch_size,
    label_mode="categorical",  # for categorical_crossentropy
    shuffle=False
)

# Add prefetching for performance
AUTOTUNE = tf.data.AUTOTUNE
train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)
test_dataset = test_dataset.prefetch(buffer_size=AUTOTUNE)

# %%
# Get class names
class_names = sorted(os.listdir('data/train'))

# %%
class_names

# %%
train_dir = 'data/train'
test_dir = 'data/test'

# %% [markdown]
# ## Plot an image from TensorFlow Datasets

# %%
import matplotlib.pyplot as plt
import numpy as np

# Get one batch of images and labels
images, labels = next(iter(train_dataset))  # Use train_dataset instead of train_data

# Plot the first 5 images from the batch
plt.figure(figsize=(15, 5))
for i in range(5):
    ax = plt.subplot(1, 5, i + 1)
    plt.imshow(images[i].numpy().astype("uint8")) # Convert to numpy array and uint8 for plotting
    plt.title(class_names[np.argmax(labels[i])])
    plt.axis("off")

# %% [markdown]
# ## Creating modelling callbacks
# callbacks used:
# * Tensorboard
# * ModelCheckpoint
# * Early Stopping

# %%
# Create tensorboard Callback
from helper_functions import create_tensorboard_callback

# Model Checkpoint Callback
checkpoint_path = "model_checpoint/cp.weights.h5"
model_checkpoint = tf.keras.callbacks.ModelCheckpoint(checkpoint_path,
                                                      monitor = "val_acc",
                                                      save_best_only = True,
                                                      save_weights_only = True,
                                                      verbose = 0)

# Early Stopping Callbacks
early_stopping = tf.keras.callbacks.EarlyStopping(monitor = "val_loss",
                                                  patience = 3,
                                                  verbose = 0,
                                                  restore_best_weights = True)

# %% [markdown]
# ## Setup mixed precision training

# %% [markdown]
# Mixed precision training involves using a mix of float16 and float32 tensors to make better use of your GPU's memory.

# %%
# Turn on mixed precision training
from tensorflow.keras import mixed_precision
mixed_precision.set_global_policy("mixed_float16")

# %% [markdown]
# ## Build Feature Extraction Model

# %%
from tensorflow.keras import layers
from tensorflow.keras import preprocessing

# %%
# Create base model
input_shape = (224, 224, 3)
base_model = tf.keras.applications.EfficientNetB0(include_top = False)
base_model.trainable = False

# Create functional model
inputs = layers.Input(shape = input_shape, name = "Input_layer")
# No rescaling required since efficientnet models have built in rescaling layers
x = base_model(inputs, training = False)
x = layers.GlobalAveragePooling2D(name = "pooling_layer")(x)
x = layers.Dense(len(class_names))(x)
# Some parts (like loss computation and output activation) require float32 to maintain numerical stability.
outputs = layers.Activation("softmax", dtype = tf.float32, name = "softmax_float32")(x)

model = tf.keras.Model(inputs, outputs)

# %%
# Compile the model
model.compile(loss = "categorical_crossentropy",
              optimizer = tf.keras.optimizers.Adam(),
              metrics = ['accuracy'])

# %%
model.summary()

# %% [markdown]
# ### Checking layer dtype policies (are we using mixed precision?)

# %%
for layer in model.layers:
  print(layer.name, layer.trainable, layer.dtype, layer.dtype_policy)

# %% [markdown]
# Going through above we see"
#   * `layer.name (str)` : a layer's human-readable name, can be defined by the name parameter on construction
#   * `layer.trainable (bool)` : whether or not a layer is trainable (all of our layers are trainable except the efficientnetb0 layer since we set it's trainable attribute to False
#   * `layer.dtype` : the data type a layer stores its variables in
#   * `layer.dtype_policy `: the data type a layer computes in

# %% [markdown]
# ### Fitting the model

# %%
history_101_food_classes_feature_extraction = model.fit(train_dataset,
                                                        epochs = 3,
                                                        steps_per_epoch = len(train_dataset),
                                                        validation_data = test_dataset,
                                                        validation_steps = int(0.15 * len(test_dataset)),
                                                        callbacks = [create_tensorboard_callback(dir_name = "training_logs",
                                                                                                 experiment_name = "efficientnetb0_101_classes_all_data_feature_extraction"),
                                                                     model_checkpoint,
                                                                     early_stopping])

# %%
# Evaluate model on whole test dataset
results_feature_extract_model = model.evaluate(test_dataset)
results_feature_extract_model

# %% [markdown]
# ## Fine-Tuning our model

# %%
# Unfreeze all the layers
base_model.trainable = True

# Re freeze all except last 15 layers
for layer in base_model.layers[:-15]:
  layer.trainable = False

# %%
# Recompile the model
model.compile(loss = "categorical_crossentropy",
              optimizer = tf.keras.optimizers.Adam(learning_rate = 0.0001),
              metrics = ['accuracy'])

# %%
# Refitting the model for 5 more epochs
history_101_food_classes_fine_tune = model.fit(train_dataset,
                                               epochs = 8,
                                               steps_per_epoch = len(train_dataset),
                                               validation_steps = int(0.15 * len(test_dataset)),
                                               validation_data = test_dataset,
                                               initial_epoch = history_101_food_classes_feature_extraction.epoch[-1],
                                               callbacks = [create_tensorboard_callback(dir_name = "training_logs",
                                                                                                 experiment_name = "efficientnetb0_101_classes_all_data_feature_extraction"),
                                                                     model_checkpoint,
                                                                     early_stopping])

# %%
# Evaluate model on whole test dataset
results_fine_tuned_model = model.evaluate(test_dataset)
results_fine_tuned_model

# %%
# Compare histories:
compare_historys(original_history = history_101_food_classes_feature_extraction,
                 new_history = history_101_food_classes_fine_tune)

# %% [markdown]
# ## Saving and Loading our model and model_weights

# %%
# Saving our model
model.save("/content/drive/MyDrive/Food Vision 101/fine_tuned.h5")

# %%
# Saving our model's weights
model.save_weights("/content/drive/MyDrive/Food Vision 101/efficientnetb0_food101_fine_tuned_weights.weights.h5")

# %% [markdown]
# ## Comparing results with TensorBoard Callback

# %%
# %load_ext tensorboard
# %tensorboard --logdir training_logs

# %% [markdown]
# ## Evaluation Metrics:

# %%
def evaluation_metrics(y_true, y_pred, model):
  '''
  y_true = the actual value of the labels
  y_pred = the predicted value of the labels
  model = the name of the model
  '''
  from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

  # Calculate evaluation metrics
  return {"Accuracy: ": accuracy_score(y_true, y_pred),
          "Precision: ": precision_score(y_true, y_pred, average='weighted'),
          "Recall: ": recall_score(y_true, y_pred, average='weighted'),
          "F1-Score: ": f1_score(y_true, y_pred, average='weighted')}

# %%
import numpy as np

# Predict on the test data
y_pred_probs = model.predict(test_dataset, verbose=1)  # shape: (num_samples, num_classes)
y_pred = np.argmax(y_pred_probs, axis=1)            # get predicted class indices

# %%
import numpy as np

# Get actual labels from the generator
y_true = np.concatenate([y for x, y in test_dataset], axis=0)
#cant use test_dataset cuz Once wrapped in a tf.data.Dataset, it no longer has .classes like ImageDataGenerator.flow_from_directory() does.  # shape: (num_samples,)

# %%
model_result = evaluation_metrics(np.argmax(y_true, axis=1), y_pred, model)

# %%
model_result

# %% [markdown]
# ## Model Deployment

# %%
# %%writefile model.py
# Create base model
def create_model(input_shape = (224, 224, 3)):

  base_model = tf.keras.applications.EfficientNetB0(include_top = False)
  base_model.trainable = False

  # Create functional model
  inputs = layers.Input(shape = input_shape, name = "Input_layer")
  # No rescaling required since efficientnet models have built in rescaling layers
  x = base_model(inputs, training = False)
  x = layers.GlobalAveragePooling2D(name = "pooling_layer")(x)
  x = layers.Dense(len(class_names))(x)
  # Some parts (like loss computation and output activation) require float32 to maintain numerical stability.
  outputs = layers.Activation("softmax", dtype = tf.float32, name = "softmax_float32")(x)

  model = tf.keras.Model(inputs, outputs)
  return model

# %%
# %%writefile app.py
import gradio as gr
import tensorflow as tf
import numpy as np

import tensorflow as tf


# Dummy Cast layer to fix loading issue from mixed precision training
class Cast(tf.keras.layers.Layer):
    def __init__(self, dtype=tf.float32, **kwargs):
        super().__init__(**kwargs)
        self._dtype = dtype

    def call(self, inputs):
        return tf.cast(inputs, self._dtype)

# Optional: Softmax Activation that TensorFlow sometimes names weirdly during serialization
class Activation(tf.keras.layers.Activation):
    pass

custom_objects = {
    "Cast": Cast,
    "Activation": Activation,  # Handles 'softmax_float32'
}

# Load the model
model = tf.keras.models.load_model(
    "fine_tuned.h5",
    custom_objects=custom_objects
)


def predict(image):
    # Preprocess the image for your model
    image = tf.image.resize(image, [224, 224])          # Resize to model input size
    image = tf.cast(image, tf.float32)                  # Cast to float32
    image = tf.keras.applications.imagenet_utils.preprocess_input(image)
    image = tf.expand_dims(image, axis=0)               # Add batch dimension

    # Make prediction
    prediction = model.predict(image)

    # Get class labels (replace with your actual class names)
    class_names = ['apple_pie',
 'baby_back_ribs',
 'baklava',
 'beef_carpaccio',
 'beef_tartare',
 'beet_salad',
 'beignets',
 'bibimbap',
 'bread_pudding',
 'breakfast_burrito',
 'bruschetta',
 'caesar_salad',
 'cannoli',
 'caprese_salad',
 'carrot_cake',
 'ceviche',
 'cheese_plate',
 'cheesecake',
 'chicken_curry',
 'chicken_quesadilla',
 'chicken_wings',
 'chocolate_cake',
 'chocolate_mousse',
 'churros',
 'clam_chowder',
 'club_sandwich',
 'crab_cakes',
 'creme_brulee',
 'croque_madame',
 'cup_cakes',
 'deviled_eggs',
 'donuts',
 'dumplings',
 'edamame',
 'eggs_benedict',
 'escargots',
 'falafel',
 'filet_mignon',
 'fish_and_chips',
 'foie_gras',
 'french_fries',
 'french_onion_soup',
 'french_toast',
 'fried_calamari',
 'fried_rice',
 'frozen_yogurt',
 'garlic_bread',
 'gnocchi',
 'greek_salad',
 'grilled_cheese_sandwich',
 'grilled_salmon',
 'guacamole',
 'gyoza',
 'hamburger',
 'hot_and_sour_soup',
 'hot_dog',
 'huevos_rancheros',
 'hummus',
 'ice_cream',
 'lasagna',
 'lobster_bisque',
 'lobster_roll_sandwich',
 'macaroni_and_cheese',
 'macarons',
 'miso_soup',
 'mussels',
 'nachos',
 'omelette',
 'onion_rings',
 'oysters',
 'pad_thai',
 'paella',
 'pancakes',
 'panna_cotta',
 'peking_duck',
 'pho',
 'pizza',
 'pork_chop',
 'poutine',
 'prime_rib',
 'pulled_pork_sandwich',
 'ramen',
 'ravioli',
 'red_velvet_cake',
 'risotto',
 'samosa',
 'sashimi',
 'scallops',
 'seaweed_salad',
 'shrimp_and_grits',
 'spaghetti_bolognese',
 'spaghetti_carbonara',
 'spring_rolls',
 'steak',
 'strawberry_shortcake',
 'sushi',
 'tacos',
 'takoyaki',
 'tiramisu',
 'tuna_tartare',
 'waffles']


    # Return a dictionary of class probabilities
    return {class_names[i]: float(prediction[0][i]) for i in range(len(class_names))}

# Create the Gradio interface
image_input = gr.Image(type="numpy", image_mode="RGB", label="Upload Image")
label_output = gr.Label(num_top_classes=1)

interface = gr.Interface(
    fn=predict,
    inputs=image_input,
    outputs=label_output,
    title="TensorFlow Image Classifier",
    description="Upload an image for classification",
    examples=["/content/food-101/images/cheesecake/1023543.jpg","/content/food-101/images/ceviche/1013481.jpg"]
)

# Launch the interface
interface.launch()

# %%
print(np.__version__)

# %%
model.save("fine_tuned.keras")  # Saves in the new format

# %%
from google.colab import files
uploaded = files.upload()

# %%
# Create food_classes.txt
with open("food_classes.txt", "w") as f:
    for class_name in class_names:
        f.write(class_name + "\n")

# %%
from tensorflow import keras

# Load the trained model
model = keras.models.load_model("fine_tuned.keras")

# Load class labels
classes = open("food_classes.txt").read().splitlines()

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.applications import efficientnet
from tensorflow.keras.preprocessing import image

# 1️⃣ Download food_classes.txt if missing (already created in a previous cell)
if not os.path.exists("food_classes.txt"):
    # !wget https://raw.githubusercontent.com/ShataayuM/Food-Vision-101/main/food_classes.txt

# 2️⃣ Load class labels (already created in a previous cell)
with open("food_classes.txt", "r") as f:
    class_names = [line.strip() for line in f]

# 3️⃣ Load the best trained model (use the locally saved model)
model_path = "fine_tuned.keras"
# No need to download since you saved it locally

model = tf.keras.models.load_model(model_path, compile=False)

# 4️⃣ Preprocessing function (MUST match training)
IMG_SIZE = (224, 224)
preprocess = efficientnet.preprocess_input

def predict_image(img_path):
    img = image.load_img(img_path, target_size=IMG_SIZE)
    x = image.img_to_array(img)
    x = preprocess(x)
    x = np.expand_dims(x, axis=0)

    preds = model.predict(x)
    top_indices = preds[0].argsort()[-5:][::-1]
    print("\nTop 5 Predictions:")
    for i in top_indices:
        print(f"{class_names[i]}: {preds[0][i]*100:.2f}%")

# 5️⃣ Example run (use your uploaded image)
test_image_path = "cheesecake-1-22.jpg" # Corrected filename
predict_image(test_image_path)

# %%
from google.colab import files
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import image

# Upload image
uploaded = files.upload()

# Load the trained model
model = tf.keras.models.load_model("fine_tuned.keras", compile=False)

# Load class labels
with open("food_classes.txt", "r") as f:
    class_names = [line.strip() for line in f]

for fn in uploaded.keys():
    # Load and preprocess image
    img_path = fn
    img = image.load_img(img_path, target_size=(224, 224))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = tf.keras.applications.efficientnet.preprocess_input(x)

    # Predict
    preds = model.predict(x)
    top_indices = preds[0].argsort()[-5:][::-1]

    print("\nTop 5 Predictions:")
    for i in top_indices:
        print(f"{class_names[i]}: {preds[0][i]*100:.2f}%")
